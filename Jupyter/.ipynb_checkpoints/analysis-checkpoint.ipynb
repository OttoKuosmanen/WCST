# %% [markdown]
# ::AIM::
# In here we will take in and work out how to make sense of the data that is stored from the GameLogic script.
# The aim of this is to see if the data file contains all we need.
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::
#
# 1# We import csv
#
# 2# We specify the filepath
#
# 3# We open the file and print out the data of each row.

# %%
import csv
file = "../results/data.csv"

with open(file,"r") as data:
    reader = csv.reader(data)
    for row in reader:
        print(row)
# Out:
# ['0', 'NONE', 'number', '0']
# ['0', 'shape', 'number', '0']
# ['1', 'number', 'number', '1']
# ['1', 'shapenumber', 'number', '2']
# ['0', 'NONE', 'number', '0']
# ['0', 'color', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'shape', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'color', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'shape', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'shape', 'number', '0']
# ['1', 'shapenumber', 'number', '1']
# ['0', 'color', 'number', '0']
# ['1', 'colornumber', 'number', '1']
# ['0', 'shape', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['1', 'shapenumber', 'number', '1']
# ['0', 'shape', 'number', '0']
# ['0', 'shape', 'number', '0']
# ['0', 'color', 'number', '0']
# ['0', 'colorshape', 'number', '0']
# ['0', 'shape', 'number', '0']
# ['1', 'number', 'number', '1']
# ['0', 'NONE', 'number', '0']
# ['1', 'number', 'number', '1']
# ['0', 'shape', 'number', '0']
# ['1', 'colornumber', 'number', '1']
# ['0', 'NONE', 'number', '0']
# ['1', 'colorshapenumber', 'number', '1']
# ['0', 'shape', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'shape', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'color', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['0', 'NONE', 'number', '0']
# ['1', 'colornumber', 'number', '1']
# ['0', 'color', 'number', '0']
# ['1', 'colorshapenumber', 'number', '1']
# ['1', 'number', 'number', '2']
# ['1', 'number', 'number', '3']
# ['1', 'number', 'number', '4']
# ['1', 'shapenumber', 'number', '5']
# ['1', 'shape', 'shape', '1']
# ['1', 'colorshape', 'shape', '2']
# ['1', 'shape', 'shape', '3']
# ['1', 'shape', 'shape', '4']
# ['1', 'shapenumber', 'shape', '5']
# ['0', 'NONE', 'color', '0']
# ['0', 'number', 'color', '0']
# ['0', 'number', 'color', '0']

# %% [markdown]
# Now instead of printing it we unpack the values into tuples and save them to a list.

# %%
results = []
with open(file,"r") as data:
    reader = csv.reader(data)
    for row in reader:
        results.append(tuple(row))

print(results[0])
# Out:
# ('0', 'NONE', 'number', '0')

# %% [markdown]
# Then lets start simple analysis.
#
# We have to keep in mind the that the tuple indexing carries with it information about the values:
# index: 0 : correct = 1, wrong = 0
# index: 1 : the category on which the chosen stimulus card and hand card were matched on
# index: 2 : the active rule
# index: 3 : winning streak

# %%
def correct_procent(results):
    cumulative = 0
    for n, data_point in enumerate(results):
        cumulative += int(data_point[0])
    correct_procent = cumulative / (n + 1)
    print(correct_procent)
    
correct_procent(results)
# Out:
# 0.3125

# %%
def completed_categories(results):
    completed = 0
    for data_point in results:
        if data_point[3] == "5":
            completed += 1
    return completed

print(completed_categories(results))
# Out:
# 2

# %%
def preservative_errors(results):
    preservative_error = 0.0
    wrong_rule = ""
    
    for data_point in results:
        if int(data_point[3]) == 0: # if there is an error
            if data_point[1] == wrong_rule: #If the wrong matching rule is repeated
                preservative_error += 1
                print("STRRRRRRR")
            
            elif data_point[1] in wrong_rule:
                wrong_rule = data_point[1]
                preservative_error += 0.5
                print(wrong_rule)
        else:
            wrong_rule = ""
            print("error resetted")
            
    return preservative_error

print(preservative_errors(results))
# Out:
# NONE
# shape
# error resetted
# error resetted
# NONE
# color
# NONE
# NONE
# shape
# NONE
# NONE
# color
# NONE
# shape
# NONE
# NONE
# shape
# error resetted
# color
# error resetted
# shape
# NONE
# error resetted
# shape
# STRRRRRRR
# color
# colorshape
# shape
# error resetted
# NONE
# error resetted
# shape
# error resetted
# NONE
# error resetted
# shape
# NONE
# NONE
# NONE
# shape
# NONE
# NONE
# color
# NONE
# NONE
# NONE
# NONE
# NONE
# NONE
# error resetted
# color
# error resetted
# error resetted
# error resetted
# error resetted
# error resetted
# error resetted
# error resetted
# error resetted
# error resetted
# error resetted
# NONE
# number
# number
# 1
